# %% [markdown]
# ### Synthetic data

# %% [markdown]
# from this everysys manual - https://www.coffema.de/content/uploads/User-Manual-Legacy-english-compressed.pdf

# %% [markdown]
# ##### Deterministic events

# %%
"""
Deterministic event-level simulator for an Eversys-style coffee machine.
Each row = one event (product_completed, cleaning, or fault), not every tick.

- Aggregates sensor stats across each product window.
- Deterministic faults and cleaning cycles.
- Writes exactly TARGET_ROWS rows (by truncation if needed).
"""

from __future__ import annotations
from dataclasses import dataclass, field
from datetime import datetime, timedelta
from typing import Dict, Any, List, Optional
import csv
import random
import numpy as np

# --------------------------- Config ---------------------------
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

TICK_MS = 500
START_TIME = datetime(2025, 1, 1, 6, 0, 0)
OPEN_H = 6
CLOSE_H = 22
SHOT_INTERVAL_S = 25 #minimum wall-clock spacing between product starts
TARGET_ROWS = 10_000

# (id, target_ml, has_milk, foam_mode)
RECIPES = [
    ("espresso", 30, False, "OFF"),
    ("lungo", 60, False, "OFF"),
    ("americano", 150, False, "OFF"),
    ("cappuccino", 180, True, "AUTO"),
    ("latte", 250, True, "AUTO"),
    ("choco", 220, True, "EVERFOAM"),
]
SIDES = ["LEFT", "RIGHT", "BOTH"] # what side of coffee machine its using

def rint(a, b): return random.randint(a, b)

def durations(recipe_id: str) -> Dict[str, int]:
    if recipe_id in {"espresso", "lungo"}:
        return dict(grind=rint(4,8), preinf=rint(4,10), extract=rint(18,42), milk=0)
    elif recipe_id in {"americano"}:
        return dict(grind=rint(4,8), preinf=rint(5,10), extract=rint(28,50), milk=0)
    elif recipe_id in {"cappuccino","latte"}:
        return dict(grind=rint(6,12), preinf=rint(6,12), extract=rint(22,46), milk=rint(12,30))
    else:
        return dict(grind=rint(6,12), preinf=rint(6,12), extract=rint(26,52), milk=rint(14,34))

# Deterministic faults
SHOT_FAULTS = {
    23:  [dict(code="W-004", kind="warning", stage="EXTRACT", desc="Low flow left")],
    37:  [dict(code="W-005", kind="warning", stage="EXTRACT", desc="Low flow right")],
    53:  [dict(code="W-011", kind="warning", stage="PREINFUSE", desc="Brew init fail left")],
    59:  [dict(code="W-012", kind="warning", stage="PREINFUSE", desc="Brew init fail right")],
}
ABS_FAULTS = [
    dict(offset_s=3*3600, code="E-012", kind="error", desc="Milk unit disconnected", clear_after_s=200),
    dict(offset_s=5*3600, code="E-199", kind="error", desc="Display comm error (lockout)", clear_after_s=150),
]

# Cleaning schedule (before these shots)
CLEANING_AT_SHOTS = [200, 400, 600, 800, 1000, 1200]
CLEANING_TICKS = 180  # 90s

# --------------------------- State models ---------------------------
@dataclass
class Grinder:
    rpm: float = 0.0
    current_a: float = 0.0
    temp_c: float = 25.0
    hopper_pct: float = 100.0
    present: bool = True

@dataclass
class BrewSide:
    pressure_bar: float = 0.0
    temp_c: float = 70.0
    flow_ml_s: float = 0.0
    init_ok: bool = True
    timer_s: float = 0.0

@dataclass
class Boiler:
    left_c: float = 88.0
    right_c: float = 88.0
    pressure_bar: float = 1.0

@dataclass
class Milk:
    connected: bool = True
    milk_temp_c: float = 3.5
    level_pct: float = 100.0
    pump_on: bool = False
    foam_mode: str = "OFF"

@dataclass
class Machine:
    mode: str = "IDLE"
    warning_code: Optional[str] = None
    error_code: Optional[str] = None

    G1: Grinder = field(default_factory=Grinder)
    G2: Grinder = field(default_factory=Grinder)
    brewL: BrewSide = field(default_factory=BrewSide)
    brewR: BrewSide = field(default_factory=BrewSide)
    boiler: Boiler = field(default_factory=Boiler)
    milk: Milk = field(default_factory=Milk)

# --------------------------- Helpers ---------------------------
def clip(x, lo, hi): return hi if x > hi else lo if x < lo else x
def n(mu, sigma): return float(np.random.normal(mu, sigma))
def within_hours(t: datetime) -> bool: return OPEN_H <= t.hour < CLOSE_H
def pick_recipe(i: int): return RECIPES[(i-1) % len(RECIPES)]
def pick_side(i: int): return SIDES[(i-1) % len(SIDES)]
def stage_key(stage: str) -> str:
    return {"GRIND":"grind","PREINFUSE":"preinf","EXTRACT":"extract","MILK":"milk"}[stage]

# --------------------------- Aggregator ---------------------------
class RunningAgg:
    def __init__(self):
        self.sums: Dict[str, float] = {}
        self.count: int = 0
    def add(self, **values: float):
        for k,v in values.items():
            self.sums[k] = self.sums.get(k, 0.0) + float(v)
        self.count += 1
    def avg(self) -> Dict[str, float]:
        if self.count == 0: return {k: 0.0 for k in self.sums.keys()}
        return {k: self.sums[k] / self.count for k in self.sums.keys()}

# --------------------------- Fault logic ---------------------------
class Faults:
    def __init__(self, start_time: datetime):
        self.to_clear_at_tick: Dict[str, int] = {}
        self.abs_faults = []
        for f in ABS_FAULTS:
            raise_ts = start_time + timedelta(seconds=f["offset_s"])
            clear_ts = raise_ts + timedelta(seconds=f["clear_after_s"])
            self.abs_faults.append(dict(raise_ts=raise_ts, clear_ts=clear_ts, **f))
    def schedule_clear(self, key: str, clear_at_tick: int):
        self.to_clear_at_tick[key] = clear_at_tick
    def inject_shot_faults(self, m: Machine, stage: str, *, tick_idx: int, shot_idx: int, rid: str):
        for fault in SHOT_FAULTS.get(shot_idx, []):
            if fault["stage"] == stage:
                m.warning_code = fault["code"]
                if fault["code"] in {"W-011"}: m.brewL.init_ok = False
                if fault["code"] in {"W-012"}: m.brewR.init_ok = False
                clear_ticks = 40 if fault["code"] in {"W-004","W-005"} else 70
                self.schedule_clear(fault["code"], tick_idx + clear_ticks)
    def inject_abs_faults(self, m: Machine, now: datetime, *, tick_idx: int):
        for f in self.abs_faults:
            if now == f["raise_ts"]:
                m.error_code = f["code"]
                if f["code"] == "E-012": m.milk.connected = False
                if f["code"] == "E-199": m.mode = "ERROR_LOCKOUT"
            if now == f["clear_ts"]:
                if f["code"] == "E-012": m.milk.connected = True
                if f["code"] == "E-199" and m.mode == "ERROR_LOCKOUT": m.mode = "IDLE"
                if m.error_code == f["code"]: m.error_code = None
    def maybe_clear(self, m: Machine, *, tick_idx: int):
        to_clear = [k for k,t in self.to_clear_at_tick.items() if tick_idx >= t]
        for key in to_clear:
            if key in {"W-011","W-012"}:
                m.brewL.init_ok = True
                m.brewR.init_ok = True
            if m.warning_code == key: m.warning_code = None
            del self.to_clear_at_tick[key]

# --------------------------- CSV writer (robust) ---------------------------
def write_csv(path: str, rows: List[Dict[str, Any]]):
    if not rows:
        return
    # Build UNION of all keys so later rows with extra fields don't crash
    all_cols = set()
    for r in rows:
        all_cols.update(r.keys())
    cols = sorted(all_cols)
    with open(path, "w", newline="") as f:
        w = csv.DictWriter(f, fieldnames=cols, extrasaction="ignore")
        w.writeheader()
        for r in rows:
            # fill missing keys with ""
            w.writerow({c: r.get(c, "") for c in cols})

# --------------------------- Simulation ---------------------------
def simulate_event_agg(target_rows: int) -> List[Dict[str, Any]]:
    m = Machine()
    rows: List[Dict[str, Any]] = []
    now = START_TIME
    tick = 0
    shot_idx = 0
    cleaning_cycle_id = 0
    faults = Faults(START_TIME)

    active = None
    cleaning_ticks = 0
    next_shot_earliest_ts = now

    def start_product(ts: datetime):
        nonlocal shot_idx, active
        shot_idx += 1
        rid, target_ml, has_milk, foam_mode = pick_recipe(shot_idx)
        side = pick_side(shot_idx)
        durs = durations(rid)
        active = dict(
            rid=rid, side=side, target_ml=target_ml, has_milk=has_milk, foam=foam_mode,
            remaining=durs.copy(), stage="GRIND", started_ts=ts, ml=0.0,
            agg_grind=RunningAgg(), agg_extract=RunningAgg(), agg_milk=RunningAgg()
        )
        m.milk.foam_mode = foam_mode
        m.mode = "BREWING"

    def finish_product(ts: datetime):
        nonlocal active
        g_avg = active["agg_grind"].avg()
        e_avg = active["agg_extract"].avg()
        milk_avg = active["agg_milk"].avg()
        rows.append(dict(
            ts=ts.isoformat(), type="product_completed",
            product_id=active["rid"], side=active["side"], shot_idx=shot_idx,
            cleaning_cycle_id=0,  # ensure column exists consistently
            code="", severity="",
            avg_G1_rpm=g_avg.get("G1_rpm",0.0), avg_G2_rpm=g_avg.get("G2_rpm",0.0),
            avg_G1_current_a=g_avg.get("G1_current_a",0.0), avg_G2_current_a=g_avg.get("G2_current_a",0.0),
            avg_G1_temp_c=g_avg.get("G1_temp_c",0.0), avg_G2_temp_c=g_avg.get("G2_temp_c",0.0),
            avg_brewL_pressure_bar=e_avg.get("brewL_pressure_bar",0.0),
            avg_brewR_pressure_bar=e_avg.get("brewR_pressure_bar",0.0),
            avg_brewL_temp_c=e_avg.get("brewL_temp_c",0.0),
            avg_brewR_temp_c=e_avg.get("brewR_temp_c",0.0),
            avg_brewL_flow_ml_s=e_avg.get("brewL_flow_ml_s",0.0),
            avg_brewR_flow_ml_s=e_avg.get("brewR_flow_ml_s",0.0),
            total_ml=active["ml"], avg_milk_temp_c=milk_avg.get("milk_temp_c",0.0),
            warning_code=m.warning_code or "", error_code=m.error_code or "",
            description=f"{active['rid']} ({active['side']}) completed"
        ))
        active = None
        m.mode = "IDLE"

    def start_cleaning(ts: datetime):
        nonlocal cleaning_cycle_id, cleaning_ticks
        cleaning_cycle_id += 1
        cleaning_ticks = CLEANING_TICKS
        rows.append(dict(
            ts=ts.isoformat(), type="cleaning_started",
            cleaning_cycle_id=cleaning_cycle_id, product_id="", side="", shot_idx=0,
            code="", severity="", description=f"Cleaning {cleaning_cycle_id} started"
        ))
        m.mode = "CLEANING"
        # deterministic W-006 every 3rd cycle
        if cleaning_cycle_id % 3 == 0:
            rows.append(dict(
                ts=(ts + timedelta(seconds=5)).isoformat(),
                type="fault_raised", code="W-006", severity="warning",
                cleaning_cycle_id=cleaning_cycle_id, product_id="", side="", shot_idx=0,
                description="Cleaning light barrier"
            ))
            rows.append(dict(
                ts=(ts + timedelta(seconds=65)).isoformat(),
                type="fault_cleared", code="W-006", severity="warning",
                cleaning_cycle_id=cleaning_cycle_id, product_id="", side="", shot_idx=0,
                description="Cleaning light barrier cleared"
            ))

    def finish_cleaning(ts: datetime):
        nonlocal cleaning_ticks
        cleaning_ticks = 0
        rows.append(dict(
            ts=ts.isoformat(), type="cleaning_completed",
            cleaning_cycle_id=cleaning_cycle_id, product_id="", side="", shot_idx=0,
            code="", severity="", description=f"Cleaning {cleaning_cycle_id} completed"
        ))
        m.mode = "IDLE"

    # Main loop (over-generate then truncate)
    while len(rows) < target_rows * 2:
        faults.inject_abs_faults(m, now, tick_idx=tick)
        faults.maybe_clear(m, tick_idx=tick)

        if active is None and (shot_idx + 1) in CLEANING_AT_SHOTS and cleaning_ticks == 0:
            start_cleaning(now)

        if cleaning_ticks > 0:
            cleaning_ticks -= 1
            if cleaning_ticks == 0:
                finish_cleaning(now)

        if (active is None and cleaning_ticks == 0 and within_hours(now)
            and m.mode != "ERROR_LOCKOUT" and now >= next_shot_earliest_ts):
            start_product(now)
            next_shot_earliest_ts = now + timedelta(seconds=SHOT_INTERVAL_S)

        if active is not None:
            stage = active["stage"]
            rid = active["rid"]
            k = stage_key(stage)

            # First tick of this stage window → inject shot faults deterministically
            if active["remaining"][k] == durations(rid)[k]:
                faults.inject_shot_faults(m, stage, tick_idx=tick, shot_idx=shot_idx, rid=rid)

            # Stage logic + aggregate sampling
            if stage == "GRIND":
                g = active["agg_grind"]
                m.G1.rpm = clip(n(1500,60),1300,1700)
                m.G2.rpm = clip(n(1450,70),1250,1700)
                m.G1.current_a = clip(n(2.0,0.3),1.0,3.5)
                m.G2.current_a = clip(n(1.9,0.35),0.9,3.5)
                g.add(G1_rpm=m.G1.rpm,G2_rpm=m.G2.rpm,
                      G1_current_a=m.G1.current_a,G2_current_a=m.G2.current_a,
                      G1_temp_c=m.G1.temp_c,G2_temp_c=m.G2.temp_c)

            elif stage == "PREINFUSE":
                m.brewL.pressure_bar = clip(m.brewL.pressure_bar + 1.0, 0, 9.5)
                m.brewR.pressure_bar = clip(m.brewR.pressure_bar + 1.0, 0, 9.5)
                m.brewL.temp_c = clip(m.brewL.temp_c + 0.6, 70, 100)
                m.brewR.temp_c = clip(m.brewR.temp_c + 0.6, 70, 100)

            elif stage == "EXTRACT":
                e = active["agg_extract"]
                lowL = (m.warning_code == "W-004")
                lowR = (m.warning_code == "W-005")
                base = 1.6 if rid=="espresso" else 2.2
                m.brewL.flow_ml_s = clip((0.6 if lowL else 1.0)*base + n(0,0.15),0.2,4.0)
                m.brewR.flow_ml_s = clip((0.6 if lowR else 1.0)*base + n(0,0.15),0.2,4.0)
                dt = TICK_MS/1000.0
                active["ml"] += (m.brewL.flow_ml_s + m.brewR.flow_ml_s) * dt
                e.add(brewL_pressure_bar=clip(n(9.0,0.4),7.5,10.5),
                      brewR_pressure_bar=clip(n(9.0,0.4),7.5,10.5),
                      brewL_temp_c=clip(n(92.0,1.2),88,98),
                      brewR_temp_c=clip(n(92.0,1.2),88,98),
                      brewL_flow_ml_s=m.brewL.flow_ml_s,
                      brewR_flow_ml_s=m.brewR.flow_ml_s)

            elif stage == "MILK":
                milk = active["agg_milk"]
                m.milk.milk_temp_c = clip(n(58.0,3.0),45,70)
                milk.add(milk_temp_c=m.milk.milk_temp_c)

            # Stage countdown and transitions
            active["remaining"][k] -= 1
            if active["remaining"][k] <= 0:
                if stage == "GRIND":
                    active["stage"] = "PREINFUSE"
                elif stage == "PREINFUSE":
                    active["stage"] = "EXTRACT"
                elif stage == "EXTRACT":
                    if active["has_milk"] and active["remaining"]["milk"] > 0:
                        active["stage"] = "MILK"
                    else:
                        finish_product(now)
                elif stage == "MILK":
                    finish_product(now)

        now += timedelta(milliseconds=TICK_MS)
        tick += 1
        if len(rows) >= target_rows * 2:
            break

    rows.sort(key=lambda r: (r["ts"], r["type"]))
    return rows[:target_rows]

# --------------------------- Main ---------------------------
if __name__ == "__main__":
    event_rows = simulate_event_agg(TARGET_ROWS)
    write_csv("event_agg_log.csv", event_rows)
    print(f"Wrote {len(event_rows)} rows to event_agg_log.csv")
# Out:
# Wrote 10000 rows to event_agg_log.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('event_agg_log.csv')

# %%
df.head()
# Out:
#    avg_G1_current_a   avg_G1_rpm  avg_G1_temp_c  avg_G2_current_a  \
# 0          2.002892  1500.525730           25.0          2.010464
# 1          2.137021  1503.042363           25.0          1.719016
# 2          1.922861  1490.223443           25.0          1.850747
# 3          2.191510  1455.925238           25.0          1.918477
# 4          2.127762  1487.097753           25.0          1.865961
#
#     avg_G2_rpm  avg_G2_temp_c  avg_brewL_flow_ml_s  avg_brewL_pressure_bar  \
# 0  1419.495374           25.0             1.599865                9.044375
# 1  1405.369004           25.0             2.255237                8.968574
# 2  1416.940783           25.0             2.237643                8.969302
# 3  1463.977802           25.0             2.190543                9.090473
# 4  1447.549631           25.0             2.256104                9.149993
#
#    avg_brewL_temp_c  avg_brewR_flow_ml_s  ...                  description  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   avg_G1_current_a        9984 non-null   float64
#  1   avg_G1_rpm              9984 non-null   float64
#  2   avg_G1_temp_c           9984 non-null   float64
#  3   avg_G2_current_a        9984 non-null   float64
#  4   avg_G2_rpm              9984 non-null   float64
#  5   avg_G2_temp_c           9984 non-null   float64
#  6   avg_brewL_flow_ml_s     9984 non-null   float64
#  7   avg_brewL_pressure_bar  9984 non-null   float64
#  8   avg_brewL_temp_c        9984 non-null   float64
#  9   avg_brewR_flow_ml_s     9984 non-null   float64
#  10  avg_brewR_pressure_bar  9984 non-null   float64
#  11  avg_brewR_temp_c        9984 non-null   float64
#  12  avg_milk_temp_c         9984 non-null   float64
#  13  cleaning_cycle_id       10000 non-null  int64
# ...

# %% [markdown]
# ##### Analysis

# %%
#!/usr/bin/env python3
"""
Analysis for synthetic event-level coffee-machine data.

Input: event_agg_log.csv (one row per event; product_completed rows carry aggregates)

Outputs (in analysis_outputs/):
- CSVs with summary tables
- PNG plots for quick inspection
"""

import os
import math
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ------------- Config -------------
DATA_PATH = "event_agg_log.csv"
OUTDIR = Path("analysis_outputs")
OUTDIR.mkdir(parents=True, exist_ok=True)


# ------------- Helpers -------------
def _savefig(name: str):
    """Save current matplotlib figure to OUTDIR/name, tight layout, 2x resolution."""
    plt.tight_layout()
    plt.savefig(OUTDIR / name, dpi=200)
    plt.close()


def _write_table(df: pd.DataFrame, name: str):
    out = OUTDIR / name
    df.to_csv(out, index=True)
    print(f"wrote table → {out}")


def _numcols(df: pd.DataFrame):
    return df.select_dtypes(include=[np.number]).columns.tolist()


# ------------- Load & basic sanitation -------------
def load_events(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    if "ts" in df.columns:
        df["ts"] = pd.to_datetime(df["ts"], errors="coerce")
    # Normalize strings to avoid NaNs vs "" surprises
    for c in ["type", "product_id", "side", "warning_code", "error_code", "code", "severity"]:
        if c in df.columns:
            df[c] = df[c].fillna("").astype(str)
    # Ensure integers where expected
    for c in ["shot_idx", "cleaning_cycle_id"]:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce").fillna(0).astype(int)
    return df


# ------------- Core analysis -------------
def analyze(df: pd.DataFrame):
    # Split event types
    products = df[df["type"] == "product_completed"].copy()
    clean_start = df[df["type"] == "cleaning_started"].copy()
    clean_end = df[df["type"] == "cleaning_completed"].copy()
    faults = df[df["type"].isin(["fault_raised", "fault_cleared"])].copy()

    # ---- 0. Event counts ----
    counts_by_type = df["type"].value_counts().rename_axis("type").to_frame("count")
    _write_table(counts_by_type, "counts_by_type.csv")

    # ---- 1. Product mix & cadence ----
    mix_recipe = (
        products.groupby("product_id")
        .size().rename("count").to_frame()
        .assign(share=lambda x: x["count"] / x["count"].sum())
        .sort_values("count", ascending=False)
    )
    _write_table(mix_recipe, "products_by_recipe.csv")

    mix_side = (
        products.groupby("side")
        .size().rename("count").to_frame()
        .assign(share=lambda x: x["count"] / x["count"].sum())
        .sort_values("count", ascending=False)
    )
    _write_table(mix_side, "products_by_side.csv")

    # Time between product completions (throughput-ish)
    products_sorted = products.sort_values("ts")
    prod_dt = products_sorted["ts"].diff().dt.total_seconds().dropna()
    cadence = pd.Series({
        "n_products": len(products_sorted),
        "median_seconds_between_products": prod_dt.median() if len(prod_dt) else np.nan,
        "p10": prod_dt.quantile(0.10) if len(prod_dt) else np.nan,
        "p90": prod_dt.quantile(0.90) if len(prod_dt) else np.nan,
    })
    _write_table(cadence.to_frame("value"), "product_cadence_summary.csv")

    # ---- 2. Cleaning intervals ----
    if not clean_start.empty:
        cs_sorted = clean_start.sort_values("ts")
        cln_dt = cs_sorted["ts"].diff().dt.total_seconds().dropna()
        cleaning_summary = pd.Series({
            "n_cycles": len(cs_sorted),
            "median_seconds_between_cleaning": cln_dt.median() if len(cln_dt) else np.nan,
            "mean_seconds_between_cleaning": cln_dt.mean() if len(cln_dt) else np.nan,
        })
        _write_table(cleaning_summary.to_frame("value"), "cleaning_interval_summary.csv")

    # ---- 3. Faults overview ----
    # a) Fault events (raised/cleared)
    if not faults.empty:
        faults_by_code = (faults[faults["type"] == "fault_raised"]
                          .groupby(["code", "severity"]).size()
                          .rename("raises").to_frame().sort_values("raises", ascending=False))
        _write_table(faults_by_code, "fault_raises_by_code.csv")

    # b) Snapshot at completion: which warnings/errors are active when products finished?
    snap_warn = products["warning_code"].replace("", np.nan).dropna()
    snap_err = products["error_code"].replace("", np.nan).dropna()
    if not snap_warn.empty:
        warn_counts = snap_warn.value_counts().rename_axis("warning_code").to_frame("count")
        _write_table(warn_counts, "snapshot_warning_at_completion.csv")
    if not snap_err.empty:
        err_counts = snap_err.value_counts().rename_axis("error_code").to_frame("count")
        _write_table(err_counts, "snapshot_error_at_completion.csv")

    # ---- 4. Product aggregate stats ----
    agg_cols = [
        "avg_G1_rpm","avg_G2_rpm",
        "avg_G1_current_a","avg_G2_current_a",
        "avg_G1_temp_c","avg_G2_temp_c",
        "avg_brewL_pressure_bar","avg_brewR_pressure_bar",
        "avg_brewL_temp_c","avg_brewR_temp_c",
        "avg_brewL_flow_ml_s","avg_brewR_flow_ml_s",
        "avg_milk_temp_c","total_ml",
    ]
    present_cols = [c for c in agg_cols if c in products.columns]
    desc_overall = products[present_cols].describe().T
    _write_table(desc_overall, "product_aggregates_overall_describe.csv")

    # By recipe
    desc_by_recipe = (
        products.groupby("product_id")[present_cols]
        .agg(["count","mean","std","min","median","max"])
    )
    _write_table(desc_by_recipe, "product_aggregates_by_recipe.csv")

    # By recipe & side
    desc_by_recipe_side = (
        products.groupby(["product_id", "side"])[present_cols]
        .agg(["count","mean","std","min","median","max"])
    )
    _write_table(desc_by_recipe_side, "product_aggregates_by_recipe_side.csv")

    # ---- 5. Fault impact: low-flow warnings on flows & volume ----
    products["low_flow_left"] = (products["warning_code"] == "W-004").astype(int)
    products["low_flow_right"] = (products["warning_code"] == "W-005").astype(int)

    flow_impact = (
        products.assign(
            any_low_flow=lambda d: (d["low_flow_left"] | d["low_flow_right"]).astype(int)
        )
        .groupby("any_low_flow")[["avg_brewL_flow_ml_s","avg_brewR_flow_ml_s","total_ml"]]
        .mean()
        .rename(index={0:"no_low_flow", 1:"low_flow"})
    )
    _write_table(flow_impact, "fault_impact_low_flow_means.csv")

    # ---- 6. Correlations among numeric aggregates ----
    corr = products[present_cols].corr(numeric_only=True)
    _write_table(corr, "correlations_product_aggregates.csv")

    # ------------- Plots -------------
    # A) Count of products by recipe
    plt.figure(figsize=(8,4))
    mix_recipe["count"].plot(kind="bar")
    plt.title("Product Count by Recipe")
    plt.xlabel("Recipe")
    plt.ylabel("Count")
    _savefig("count_by_recipe.png")

    # B) Total ml distribution
    if "total_ml" in products.columns:
        plt.figure(figsize=(7,4))
        products["total_ml"].plot(kind="hist", bins=40)
        plt.title("Distribution of Total Dispensed (ml)")
        plt.xlabel("total_ml")
        plt.ylabel("frequency")
        _savefig("hist_total_ml.png")

    # C) Total ml over time (trend)
    if "total_ml" in products.columns:
        plt.figure(figsize=(9,4))
        products_sorted.set_index("ts")["total_ml"].plot()
        plt.title("Total ml per Product Over Time")
        plt.xlabel("time")
        plt.ylabel("total_ml")
        _savefig("total_ml_over_time.png")

    # D) Flow vs low-flow warning (bar)
    if {"avg_brewL_flow_ml_s","avg_brewR_flow_ml_s"}.issubset(products.columns):
        means = products.groupby("warning_code")[["avg_brewL_flow_ml_s","avg_brewR_flow_ml_s","total_ml"]].mean()
        plt.figure(figsize=(9,4))
        means[["avg_brewL_flow_ml_s","avg_brewR_flow_ml_s"]].plot(kind="bar")
        plt.title("Mean Flow by Warning Code")
        plt.xlabel("warning_code")
        plt.ylabel("mean flow (ml/s)")
        _savefig("mean_flow_by_warning.png")

        plt.figure(figsize=(7,4))
        means["total_ml"].plot(kind="bar")
        plt.title("Mean Total ml by Warning Code")
        plt.xlabel("warning_code")
        plt.ylabel("mean total_ml")
        _savefig("mean_total_ml_by_warning.png")

    # E) Boxplot of total_ml by recipe
    if "total_ml" in products.columns:
        plt.figure(figsize=(10,5))
        # Boxplot requires grouped arrays
        data = [grp["total_ml"].values for _, grp in products.groupby("product_id")]
        labels = [name for name, _ in products.groupby("product_id")]
        plt.boxplot(data, labels=labels, showmeans=True)
        plt.title("Total ml by Recipe (boxplot)")
        plt.xlabel("Recipe")
        plt.ylabel("total_ml")
        _savefig("box_total_ml_by_recipe.png")

    print("\nAnalysis complete. See outputs in:", OUTDIR.resolve())


if __name__ == "__main__":
    if not os.path.exists(DATA_PATH):
        raise FileNotFoundError(
            f"Could not find {DATA_PATH}. Put your synthetic CSV here or update DATA_PATH."
        )
    df_events = load_events(DATA_PATH)
    analyze(df_events)
# Out:
# wrote table → analysis_outputs/counts_by_type.csv
# wrote table → analysis_outputs/products_by_recipe.csv
# wrote table → analysis_outputs/products_by_side.csv
# wrote table → analysis_outputs/product_cadence_summary.csv
# wrote table → analysis_outputs/cleaning_interval_summary.csv
# wrote table → analysis_outputs/fault_raises_by_code.csv
# wrote table → analysis_outputs/snapshot_error_at_completion.csv
# wrote table → analysis_outputs/product_aggregates_overall_describe.csv
# wrote table → analysis_outputs/product_aggregates_by_recipe.csv
# wrote table → analysis_outputs/product_aggregates_by_recipe_side.csv
# wrote table → analysis_outputs/fault_impact_low_flow_means.csv
# wrote table → analysis_outputs/correlations_product_aggregates.csv
# ...
